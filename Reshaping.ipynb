# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
# _____
#
# <a id='home'></a>
#
# # Reshaping
#
# <a target="_blank" href="https://colab.research.google.com/github/CienciaDeDatosEspacial/code_and_data/blob/main/Reshaping.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# Data frames have have different shapes. Let me use some columns from the data on fragility:

# %%
import os, pandas as pd

FragilityAll=pd.read_csv(os.path.join("archivoo","FragilityCia_isos.csv"))

# seeing long shape
fragileLong=FragilityAll.iloc[:,:3]
fragileLong
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD
# 0             .af
# 1             .al
# 2             .dz
# 3             .ao
# 4             .ag
# ..            ...
# 166           .uz
# 167           .vn
# 168           .ye
# 169           .zm
# 170           .zw
#
# [171 rows x 3 columns]

# %% [markdown]
# You notice a DF is in long shape when you see the unit of analysis repeated in more than one cell accross the rows.

# %% [markdown]
# Let me turn our **long** into **wide** shape:

# %%
# to wide
fragileWide=pd.pivot_table(fragileLong,
               values='Total', # values to use
               index=['Country'], # unit of analysis
               columns=['Year']) # the values for NEW column
# see wide
fragileWide.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 # to wide
# ----> 2 fragileWide=pd.pivot_table(fragileLong,
#       3                values='Total', # values to use
#       4                index=['Country'], # unit of analysis
#       5                columns=['Year']) # the values for NEW column
#       6 # see wide
#       7 fragileWide.head()
#
# File ~\anaconda3\envs\SDS_20232_ENRIQUE\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\envs\SDS_20232_ENRIQUE\Lib\site-packages\pandas\core\reshape\pivot.py:143, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     141 for i in values:
#     142     if i not in data:
# --> 143         raise KeyError(i)
#     145 to_filter = []
#     146 for x in keys + values:
#
# KeyError: 'Total'

# %% [markdown]
# The **wide** shape from a **pivot_table** function looks great, but pay attention:

# %%
fragileWide.columns
# Out:
# Index([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype='int64', name='Year')

# %% [markdown]
# As you see above, the country is the row _index_ (row name), not a column. You may want this:

# %%
# resetting index, keeping last index as a column
fragileWide= fragileWide.reset_index(drop=False).\
             rename_axis(index=None, columns=None) # no name for indexes

# result:
fragileWide.head()
# Out:
#                Country   2013   2014   2015   2016   2017        2018   2019  \
# 0          AFGHANISTAN  106.7  106.5  107.9  107.9  107.3  106.620768  105.0
# 1              ALBANIA   65.2   63.6   61.9   61.2   60.5   60.079308   58.9
# 2              ALGERIA   78.7   78.8   79.6   78.3   76.8   75.785052   75.4
# 3               ANGOLA   87.1   87.4   87.9   90.5   91.1   89.440296   87.8
# 4  ANTIGUA AND BARBUDA   58.0   59.0   57.8   56.2   54.8   55.611041   54.4
#
#          2020   2021
# 0  102.901187  102.1
# 1   58.753811   59.0
# 2   74.575183   73.6
# 3   87.320039   89.0
# 4   52.062352   54.9

# %% [markdown]
# Long shape is efficient in the presence of missing values:

# %%
# missing values in long format
fragileLong[fragileLong.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Total]
# Index: []

# %% [markdown]
# Wide shape will create missing values when needed:

# %%
# what cells have missing values?
fragileWide[fragileWide.isna().any(axis=1)]
# Out:
#                   Country  2013  2014  2015  2016  2017       2018  2019  \
# 27             CABO VERDE   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 31             CAPE VERDE  73.7  74.1  73.5  71.5  70.1  68.000000  66.6
# 45         CZECH REPUBLIC  39.9  39.4  37.4  40.8  40.1  39.047601   NaN
# 46                CZECHIA   NaN   NaN   NaN   NaN   NaN        NaN  37.6
# 56               ESWATINI   NaN   NaN   NaN   NaN   NaN        NaN  85.3
# 81                 ISRAEL   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 82   ISRAEL AND WEST BANK  80.8  79.5  79.4  79.7  78.9  78.533740  76.5
# 90        KYRGYZ REPUBLIC  85.7  83.9  82.2  81.1  80.3  78.634122  76.2
# 91             KYRGYZSTAN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 100             MACEDONIA  68.0  66.4  64.5  67.0  66.1  64.797158  64.6
# 125       NORTH MACEDONIA   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 129             PALESTINE   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 149       SLOVAK REPUBLIC  45.3  45.3  42.6  44.9  44.3  42.474889  40.5
# 150              SLOVAKIA   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 161             SWAZILAND  85.6  85.8  86.2  87.6  88.8  87.540650   NaN
#
#           2020  2021
# 27         NaN  64.2
# 31   64.778171   NaN
# 45   35.741616   NaN
# 46         NaN  39.3
# 56         NaN  82.5
# 81         NaN  43.0
# 82   75.123972   NaN
# 90   73.929364   NaN
# 91         NaN  76.4
# 100  62.130864   NaN
# 125        NaN  64.5
# 129        NaN  86.0
# 149  38.221815   NaN
# 150        NaN  39.0
# 161  83.000000   NaN

# %% [markdown]
# This last request shows us problems.
# As you can see, even though the data DFs were prepared by the same organization, the DFs have country names that differ among them. Here we need some **manual** changes:

# %%
# prepare changes as dict:
changes={"CABO VERDE": "CAPE VERDE",
"CZECHIA":"CZECH REPUBLIC",
"SWAZILAND":"ESWATINI",
"ISRAEL AND WEST BANK":"ISRAEL",
"KYRGYZSTAN":"KYRGYZ REPUBLIC",
"NORTH MACEDONIA":"MACEDONIA",
"SLOVAKIA": "SLOVAK REPUBLIC"}

# %% [markdown]
# Notice I am making the changes in the long shape of the DF, so that the wide shape will work fine:

# %%
# make changes using 'replace':
FragilityAll.Country.replace(to_replace=changes,inplace=True)
#then

fragileLong=FragilityAll.iloc[:,:3]

# %% [markdown]
# Let's redo the wide reshape:

# %%
# to wide shape again
fragileWide=pd.pivot_table(fragileLong,
               values='Total',
               index=['Country'],
               columns=['Year']).\
            reset_index(drop=False).\
            rename_axis(index=None, columns=None)

# verify missing
fragileWide[fragileWide.isna().any(axis=1)]
# Out:
#        Country  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 124  PALESTINE   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  86.0

# %% [markdown]
# You have to be very careful when working with countries, specially when you are including or excluding countries; which may cause you hurting someone else's feelings.
#
# For instance, here I am just keeping **rows** with no missing values:

# %%
fragileWide.dropna(inplace=True)

# %% [markdown]
# After dropping rows, I recommend you reset the indexes:

# %%
fragileWide.reset_index(drop=True,inplace=True)

# %% [markdown]
# For sure, we can turn this wide shape into a long one, using the function **melt**:

# %%
pd.melt(fragileWide, id_vars=['Country'])
# Out:
#                   Country variable  value
# 0             AFGHANISTAN     2013  106.7
# 1                 ALBANIA     2013   65.2
# 2                 ALGERIA     2013   78.7
# 3                  ANGOLA     2013   87.1
# 4     ANTIGUA AND BARBUDA     2013   58.0
# ...                   ...      ...    ...
# 1597            VENEZUELA     2021   92.6
# 1598              VIETNAM     2021   63.3
# 1599                YEMEN     2021  111.7
# 1600               ZAMBIA     2021   84.9
# 1601             ZIMBABWE     2021   99.1
#
# [1602 rows x 3 columns]

# %% [markdown]
# This would be more explicit:

# %%
fragileLong=pd.melt(fragileWide, #DF
        id_vars=['Country'], #key
        value_vars=list(range(2013,2022)), # columns in wide
        var_name='Year', # new name for long column
        value_name='Total')# new name for values

# verifying
fragileLong.head()
# Out:
#                Country  Year  Total
# 0          AFGHANISTAN  2013  106.7
# 1              ALBANIA  2013   65.2
# 2              ALGERIA  2013   78.7
# 3               ANGOLA  2013   87.1
# 4  ANTIGUA AND BARBUDA  2013   58.0
